# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %reload_ext autoreload
# %autoreload 2

# %%
import os

os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %% [raw]
# to install fieldlearn
#
# pip install --upgrade git+https://github.com/voyleg/dev.vectorization.git@feature/evaluation_eccv2020
# python setup.py build
# python setup.py install

# %%
from fieldlearn.data_generation.pvf_generator import PVFGenerator
from fieldlearn.plotting import plot_vector_field_cross

# %%
svg_path = '/home/mtaktash/data/abc_renders/abc_renders/00050001_82639ddcab054f4eb6d953b3_step_000.svg'
raster, field = PVFGenerator(128, 128, smoothing_type='no_smoothing').generate_vector_field(svg_path)

# %%
plot_vector_field_cross(raster, field, figsize=(20, 20))
